# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Timestamp

# %%
Customer_Final.describe()
# Out:
#        transaction_id    customer_Id  prod_sub_cat_code  prod_cat_code  \
# count    2.305300e+04   23053.000000       23053.000000   23053.000000
# mean     5.007348e+10  271021.746497           6.149091       3.763632
# std      2.898194e+10    2431.692059           3.726372       1.677016
# min      3.268991e+06  266783.000000           1.000000       1.000000
# 25%      2.493864e+10  268935.000000           3.000000       2.000000
# 50%      5.009313e+10  270980.000000           5.000000       4.000000
# 75%      7.533000e+10  273114.000000          10.000000       5.000000
# max      9.998755e+10  275265.000000          12.000000       6.000000
#
#                 Qty          Rate           Tax     total_amt     city_code  \
# count  23053.000000  23053.000000  23053.000000  23053.000000  23045.000000
# mean       2.432395    636.369713    248.667192   2107.308002      5.482534
# std        2.268406    622.363498    187.177773   2507.561264      2.863499
# ...

# %%
file_name = 'Customer_Final.xlsx'

Customer_Final.to_excel(file_name)

# %% [markdown]
# # 1. Merge the datasets Customers, Product Hierarchy and Transactions as Customer_Final. Ensure to keep all customers who have done transactions with us and select the join type accordingly.

# %%
df1 = pd.read_csv("E:/PYTHON PROJECT/Customer.csv")

# %%
df2 = pd.read_csv("E:\PYTHON PROJECT\prod_cat_info.csv")

# %%
df3 = pd.read_csv("E:\PYTHON PROJECT\Transactions.csv")

# %%
df1.columns
# Out:
# Index(['customer_Id', 'DOB', 'Gender', 'city_code'], dtype='object')

# %%
df2.columns
# Out:
# Index(['prod_cat_code', 'prod_cat', 'prod_sub_cat_code', 'prod_subcat'], dtype='object')

# %%
df3.columns
# Out:
# Index(['transaction_id', 'customer_Id', 'tran_date', 'prod_sub_cat_code',
#        'prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt', 'Store_type'],
#       dtype='object')

# %%
df3. rename(columns = {'cust_id':'customer_Id'}, inplace = True)
df3. rename(columns = {'prod_subcat_code':'prod_sub_cat_code'}, inplace = True)

# %%
xyz = pd.merge(df3,df1,left_on='customer_Id',right_on='customer_Id',how='left')
Customer_Final = pd.merge(xyz,df2,on=['prod_cat_code','prod_sub_cat_code'],how='left')

# %%
Customer_Final.head(10)
# Out:
#    transaction_id  customer_Id   tran_date  prod_sub_cat_code  prod_cat_code  \
# 0     80712190438       270351  28-02-2014                  1              1
# 1     29258453508       270384  27-02-2014                  5              3
# 2     51750724947       273420  24-02-2014                  6              5
# 3     93274880719       271509  24-02-2014                 11              6
# 4     51750724947       273420  23-02-2014                  6              5
# 5     97439039119       272357  23-02-2014                  8              3
# 6     45649838090       273667  22-02-2014                 11              6
# 7     22643667930       271489  22-02-2014                 12              6
# 8     79792372943       275108  22-02-2014                  3              1
# 9     50076728598       269014  21-02-2014                  8              3
#
#    Qty  Rate      Tax  total_amt Store_type         DOB Gender  city_code  \
# ...

# %% [markdown]
# # 2. Prepare a summary report for the merged data set                                                                     a. Get the column names and their corresponding data types

# %%
data_types = pd.DataFrame(Customer_Final)
  
print("Data Types of The Columns in Data Frame")
print(data_types.dtypes)
# Out:
# Data Types of The Columns in Data Frame
# transaction_id         int64
# customer_Id            int64
# tran_date             object
# prod_sub_cat_code      int64
# prod_cat_code          int64
#                       ...
# DOB                   object
# Gender                object
# city_code            float64
# prod_cat              object
# prod_subcat           object
# Length: 15, dtype: object

# %%
# another approach
Customer_Final.info
# Out:
# <bound method DataFrame.info of        transaction_id  customer_Id   tran_date  prod_sub_cat_code  \
# 0         80712190438       270351  28-02-2014                  1
# 1         29258453508       270384  27-02-2014                  5
# 2         51750724947       273420  24-02-2014                  6
# 3         93274880719       271509  24-02-2014                 11
# 4         51750724947       273420  23-02-2014                  6
# ...               ...          ...         ...                ...
# 23048     94340757522       274550  25-01-2011                 12
# 23049     89780862956       270022  25-01-2011                  4
# 23050     85115299378       271020  25-01-2011                  2
# 23051     72870271171       270911  25-01-2011                 11
# 23052     77960931771       271961  25-01-2011                 11
#
#        prod_cat_code  Qty  Rate      Tax  total_amt Store_type         DOB  \
# ...

# %% [markdown]
# # 2. Prepare a summary report for the merged data set.
# # b. Top/Bottom 10 observations

# %%
Customer_Final.head(10)
#check
# Out:
#    transaction_id  customer_Id   tran_date  prod_sub_cat_code  prod_cat_code  \
# 0     80712190438       270351  28-02-2014                  1              1
# 1     29258453508       270384  27-02-2014                  5              3
# 2     51750724947       273420  24-02-2014                  6              5
# 3     93274880719       271509  24-02-2014                 11              6
# 4     51750724947       273420  23-02-2014                  6              5
# 5     97439039119       272357  23-02-2014                  8              3
# 6     45649838090       273667  22-02-2014                 11              6
# 7     22643667930       271489  22-02-2014                 12              6
# 8     79792372943       275108  22-02-2014                  3              1
# 9     50076728598       269014  21-02-2014                  8              3
#
#    Qty  Rate      Tax  total_amt Store_type         DOB Gender  city_code  \
# ...

# %%
Customer_Final.tail(10)
# Out:
#        transaction_id  customer_Id   tran_date  prod_sub_cat_code  \
# 23043     49882891062       271982  25-01-2011                 10
# 23044     14787475597       273982  25-01-2011                  4
# 23045     50691119572       273031  25-01-2011                  6
# 23046     40893803228       272049  25-01-2011                 11
# 23047     30856003613       266866  25-01-2011                  4
# 23048     94340757522       274550  25-01-2011                 12
# 23049     89780862956       270022  25-01-2011                  4
# 23050     85115299378       271020  25-01-2011                  2
# 23051     72870271171       270911  25-01-2011                 11
# 23052     77960931771       271961  25-01-2011                 11
#
#        prod_cat_code  Qty  Rate      Tax  total_amt Store_type         DOB  \
# 23043              5    4  1330  558.600   5878.600     e-Shop  10-08-1976
# 23044              3    5   969  508.725   5353.725     e-Shop  12-10-1991
# ...

# %% [markdown]
# # 2. Prepare a summary report for the merged data set.
# # c. “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)

# %%
data2 = Customer_Final.index[Customer_Final['total_amt'] < 0]
data2
# Out:
# Int64Index([   12,    13,    14,    15,    16,    17,    54,    55,    56,
#                57,
#             ...
#             99229, 99233, 99234, 99235, 99260, 99261, 99262, 99272, 99273,
#             99274],
#            dtype='int64', length=9294)

# %%
Customer_Final[["Qty" , "Rate" , "Tax" , "total_amt"]].describe()
# Out:
#                 Qty          Rate           Tax     total_amt
# count  23053.000000  23053.000000  23053.000000  23053.000000
# mean       2.432395    636.369713    248.667192   2107.308002
# std        2.268406    622.363498    187.177773   2507.561264
# min       -5.000000  -1499.000000      7.350000  -8270.925000
# 25%        1.000000    312.000000     98.280000    762.450000
# 50%        3.000000    710.000000    199.080000   1754.740000
# 75%        4.000000   1109.000000    365.715000   3569.150000
# max        5.000000   1500.000000    787.500000   8287.500000

# %% [markdown]
# # 2. Prepare a summary report for the merged data set.
# # d. Frequency tables for all the categorical variables

# %%
Customer_Final.describe(include = "object")
# Out:
#          tran_date Store_type         DOB Gender prod_cat prod_subcat
# count        23053      23053       23053  23044    23053       23053
# unique        1129          4        3987      2        6          18
# top     13-07-2011     e-Shop  27-12-1988      M    Books       Women
# freq            35       9311          32  11811     6069        3048

# %%
Customer_Final.Store_type.value_counts()
# Out:
# e-Shop            9311
# MBR               4661
# Flagship store    4577
# TeleShop          4504
# Name: Store_type, dtype: int64

# %%
Customer_Final.prod_cat.value_counts()
# Out:
# Books               6069
# Electronics         4898
# Home and kitchen    4129
# Footwear            2999
# Clothing            2960
# Bags                1998
# Name: prod_cat, dtype: int64

# %%
Customer_Final.prod_subcat.value_counts()
# Out:
# Women                  3048
# Mens                   2912
# Kids                   1997
# Tools                  1062
# Fiction                1043
#                        ...
# Cameras                 985
# Personal Appliances     972
# Academic                967
# Computers               958
# Audio and video         952
# Name: prod_subcat, Length: 18, dtype: int64

# %%
Customer_Final.Gender.value_counts()
# Out:
# M    11811
# F    11233
# Name: Gender, dtype: int64

# %%
Customer_Final.city_code.value_counts()
# Out:
# 4.0     2422
# 3.0     2411
# 5.0     2360
# 7.0     2356
# 10.0    2333
# 8.0     2330
# 2.0     2270
# 1.0     2258
# 9.0     2178
# 6.0     2127
# Name: city_code, dtype: int64

# %% [markdown]
# # 3. Generate histograms for all continuous variables and frequency bars for categorical variables.

# %%
cont_v = ["Qty" , "Rate","Tax","total_amt"]
cat_v = ["Store_type","DOB","Gender","city_code"]

# %%
hist = Customer_Final[cont_v].hist(bins=12)

# %%
fig, ax = plt.subplots()
Customer_Final['Gender'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
Customer_Final
# Out:
#        transaction_id  customer_Id   tran_date  prod_sub_cat_code  \
# 0         80712190438       270351  28-02-2014                  1
# 1         29258453508       270384  27-02-2014                  5
# 2         51750724947       273420  24-02-2014                  6
# 3         93274880719       271509  24-02-2014                 11
# 4         51750724947       273420  23-02-2014                  6
# ...               ...          ...         ...                ...
# 23048     94340757522       274550  25-01-2011                 12
# 23049     89780862956       270022  25-01-2011                  4
# 23050     85115299378       271020  25-01-2011                  2
# 23051     72870271171       270911  25-01-2011                 11
# 23052     77960931771       271961  25-01-2011                 11
#
#        prod_cat_code  Qty  Rate      Tax  total_amt Store_type         DOB  \
# 0                  1   -5  -772  405.300  -4265.300     e-Shop  26-09-1981
# ...

# %% [markdown]
# # 4. Calculate the following information using the merged dataset :
# # a. Time period of the available transaction data

# %%
print("Time period of available transaction starts from", Customer_Final["tran_date"].min(),"ends at",Customer_Final["tran_date"].max())
# Out:
# Time period of available transaction starts from 1/1/2012 ends at 9/9/2013

# %% [markdown]
# # 4. Calculate the following information using the merged dataset :
# # b. Count of transactions where the total amount of transaction was negative

# %%
np.sum(Customer_Final.total_amt < 0)
# Out:
# 2177

# %% [markdown]
# # 5. Analyze which product categories are more popular among females vs male customers.

# %%
pd.set_option('display.max_rows' , 12)
z = prod_cat.groupby(["Gender" , "prod_cat_code" , ]).count().reset_index().sort_values("customer_Id" , ascending = False)
z
# Out:
#    Gender  prod_cat_code  customer_Id
# 10      M              5         3116
# 4       F              5         2949
# 8       M              3         2570
# 2       F              3         2328
# 11      M              6         2134
# 5       F              6         1994
# 1       F              2         1529
# 6       M              1         1518
# 7       M              2         1469
# 0       F              1         1439
# 9       M              4         1004
# 3       F              4          994

# %% [markdown]
# # 6. Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
df1.shape
# Out:
# (5647, 4)

# %%
total_no_of_cust = Customer_Final.customer_Id.unique()
len(total_no_of_cust)
# Out:
# 5506

# %%
Customer_Final.groupby('city_code')['customer_Id'].nunique()
# Out:
# city_code
# 1.0     535
# 2.0     546
# 3.0     576
# 4.0     569
# 5.0     570
# 6.0     516
# 7.0     563
# 8.0     551
# 9.0     532
# 10.0    546
# Name: customer_Id, dtype: int64

# %%
print("Max customer from city is :" , max_cust[max_cust["customer_Id"]==max_cust["customer_Id"].max()]["customer_Id"])
# Out:
# Max customer from city is : city_code
# 4.0    5961
# Name: customer_Id, dtype: int64

# %%
 city code 4 has maximum customers and they are 10.64% of the total customers

# %% [markdown]
# # 7. Which store type sells the maximum products by value and by quantity?

# %%
Customer_Final.Store_type.unique()
# Out:
# array(['TeleShop', 'MBR', 'e-Shop', 'Flagship store'], dtype=object)

# %%
a = Customer_Final.groupby(['Store_type']).sum()[['Qty' , "total_amt"]]
a.style.highlight_max(color = 'orange' , axis = 0)
# Out:
# <style type="text/css">
# #T_9a842_row3_col0, #T_9a842_row3_col1 {
#   background-color: orange;
# }
# </style>
# <table id="T_9a842_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Qty</th>
#       <th class="col_heading level0 col1" >total_amt</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a842_level0_row0" class="row_heading level0 row0" >Flagship store</th>
#       <td id="T_9a842_row0_col0" class="data row0 col0" >27600</td>
#       <td id="T_9a842_row0_col1" class="data row0 col1" >24072659.260000</td>
#     </tr>
#     <tr>
#       <th id="T_9a842_level0_row1" class="row_heading level0 row1" >MBR</th>
#       <td id="T_9a842_row1_col0" class="data row1 col0" >27869</td>
# ...

# %% [markdown]
# # 8. What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
tot_amt_earned = Customer_Final[Customer_Final["prod_cat"].isin(["Clothing"]) | Customer_Final["prod_cat"].isin(["Electronics"])]

# %%
print(" total amount earned from the Electronics and Clothing categories from Flagship Stores :" ,tot_amt_earned[tot_amt_earned["Store_type"].isin(["Flagship store"])]["total_amt"].sum())
# Out:
#  total amount earned from the Electronics and Clothing categories from Flagship Stores : 3409559.27

# %% [markdown]
# # 9. What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
d = Customer_Final[Customer_Final["Gender"].isin(["M"]) & Customer_Final["prod_cat"].isin(["Electronics"])]["total_amt"].sum()
print("Total amount earned from Male customers under the Electronics category is :" , d)
# Out:
# Total amount earned from Male customers under the Electronics category is : 5703109.424999999

# %% [markdown]
# # 10. How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
temp = Customer_Final[Customer_Final["total_amt"]>= 0 ]
temp
g = temp[["transaction_id" , "customer_Id"]].groupby('customer_Id').count().reset_index()
g = g[g["transaction_id"]>10]
g
# Out:
#       customer_Id  transaction_id
# 4          266794              11
# 2426       270535              11
# 2606       270803              11
# 3867       272741              11
# 4032       273014              11
# 4815       274227              11

# %% [markdown]
# # 11. For all customers aged between 25 - 35, find out:
# # a. What was the total amount spent for “Electronics” and “Books” product categories?

# %%
def calculate_age(born):
    year = born.split('-')[2] 
    today = 2022
    return today - int(year) +1

# %%
# Customer_Final['age'] = Customer_Final['DOB'].apply(calculate_age)
# Customer_Final['age']
cust_25_35 = Customer_Final[(Customer_Final.age>=25) & (Customer_Final.age<=35)]
cust_25_35
# Out:
#        transaction_id  customer_Id   tran_date  prod_sub_cat_code  \
# 2         51750724947       273420  24-02-2014                  6
# 4         51750724947       273420  23-02-2014                  6
# 23        91116291703       268509  20-02-2014                  1
# 28        88853694830       268444  20-02-2014                  4
# 37        31384765864       267058  19-02-2014                  3
# ...               ...          ...         ...                ...
# 23033     32887353269       268885  25-01-2011                  3
# 23034     28972634039       275227  25-01-2011                  9
# 23035     42161597232       267094  25-01-2011                  3
# 23038     61812307223       274306  25-01-2011                  4
# 23044     14787475597       273982  25-01-2011                  4
#
#        prod_cat_code  Qty  Rate      Tax  total_amt      Store_type  \
# 2                  5   -2  -791  166.110  -1748.110        TeleShop
# ...

# %%
# g = temp[["transaction_id" , "customer_Id"]].groupby('customer_Id').count().reset_index()

# %%
tot_amt_spent = Customer_Final[Customer_Final["prod_cat"].isin(["Books"]) | Customer_Final["prod_cat"].isin(["Electronics"])]
print(" total amount spent for Electronics and Books product categories :",tot_amt_spent)
# Out:
#  total amount spent for Electronics and Books product categories :        transaction_id  customer_Id   tran_date  prod_sub_cat_code  \
# 1         29258453508       270384  27-02-2014                  5
# 2         51750724947       273420  24-02-2014                  6
# 4         51750724947       273420  23-02-2014                  6
# 5         97439039119       272357  23-02-2014                  8
# 9         50076728598       269014  21-02-2014                  8
# ...               ...          ...         ...                ...
# 23044     14787475597       273982  25-01-2011                  4
# 23045     50691119572       273031  25-01-2011                  6
# 23048     94340757522       274550  25-01-2011                 12
# 23051     72870271171       270911  25-01-2011                 11
# 23052     77960931771       271961  25-01-2011                 11
#
#        prod_cat_code  Qty  Rate      Tax  total_amt Store_type         DOB  \
# ...

# %% [markdown]
# # 11. For all customers aged between 25 - 35, find out:
# # b. What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?

# %%
Customer_Final['tran_date']=pd.to_datetime(Customer_Final['tran_date'])

# %%
tran =Customer_Final.loc[(Customer_Final["age"]>25) & (Customer_Final["age"] <35 ) & (Customer_Final['tran_date']>'01-01-2014') & (Customer_Final['tran_date']<'01-03-2014') , "total_amt"].sum()
tran
# Out:
# 7686.380000000001
